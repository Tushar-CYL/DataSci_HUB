# %%
import undetected_chromedriver as uc

import time 
 
options = uc.ChromeOptions() 
options.headless = False  # Set headless to False to run in non-headless mode

driver = uc.Chrome(use_subprocess=True, options=options) 
driver.get("https://www.google.com/")

# %%
import undetected_chromedriver as uc

import time 
 
options = uc.ChromeOptions() 
options.headless = False  # Set headless to False to run in non-headless mode

driver = uc.Chrome(use_subprocess=True, options=options) 
driver.get("https://www.bing.com/")

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.google.com/")

# %%
# linkedin password and id


# Id = driver.find_element(By.XPATH,"/html/body/main/section[1]/div/div/form/div[1]/div[1]/div/div/input")
# Id.send_keys("tusharpatra753@gmail.com")
# password = driver.find_element(By.XPATH,"/html/body/main/section[1]/div/div/form/div[1]/div[2]/div/div/input")
# password.send_keys("993355@Tushar")
# submit1 = driver.find_element(By.XPATH,"/html/body/main/section[1]/div/div/form/div[2]/button")
# submit1.submit()

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('kolkata_linkedin.csv')
# dr = pd.DataFrame(df)
df
# Out:
#                                                    name
# 0      https://in.linkedin.com/company/omni-manual-p...
# 1         https://in.linkedin.com/company/radheinfotech
# 2             https://www.linkedin.com/company/digichal
# 3         https://in.linkedin.com/company/wearepapiriko
# 4      https://in.linkedin.com/company/cognisoft-tec...
# ...                                                 ...
# 2665   https://in.linkedin.com/company/eframe-infome...
# 2666     https://in.linkedin.com/company/brain-solution
# 2667          https://in.linkedin.com/company/mshtalent
# 2668   https://in.linkedin.com/company/sb3-software-...
# 2669         https://in.linkedin.com/company/ready2help
#
# [2670 rows x 1 columns]

# %%
from selenium.webdriver.common.by import By

# %%
import csv
import time

# %%
# # google path

# for index, row in df.iterrows():
#     i = row['name']
   
   
#     b = driver.find_element(By.XPATH, "/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea")
#     b.send_keys(str(i))
#     b.submit()
    
    
#     search1st = driver.find_element(By.CLASS_NAME, "VuuXrf")
#     search1st.click()
    
    
   
    
#     # click 3 tims
#     cl1 = driver.find_element(By.CLASS_NAME, "artdeco-button__text")
#     cl1.click()
#     cl1.click()
#     cl1.click()
    
    
    
    
#     # for x in range(20):
#     #     try:
#     #         btn =  driver.find_element(By.XPATH,"/html/body/div[5]/div[3]/div/div[2]/div/div[2]/main/div[2]/div/div[1]/div/div/section/div[2]/ul/li[4]/div/div/div/button["+str(x)+"]")
#     #         print(btn.text)
#     #     except:
#     #         break
        
#     driver.back()
#     # driver.back()
#     driver.back()

# %%
import csv

for index, row in df.iterrows():
    i = row['name']
   
   
    b = driver.find_element(By.ID, "sb_form_q")
    b.send_keys(str(i))
    b.submit()
    
    
    search1st = driver.find_element(By.CLASS_NAME, "tptt")
    search1st.click()
    
    
    # people = driver.find_element(By.XPATH,"/html/body/div[5]/div[3]/div/div[2]/div/div[2]/main/div[1]/section/div/div[2]/div[3]/nav/ul/li[5]")
    # people.click()
    driver.get(str(i)+"/people/")
    
    # btn = driver.find_element(By.XPATH,"/html/body/div[5]/div[3]/div/div[2]/div/div[2]/main/div[2]/div/div[1]/div/button/svg")
    # btn.click()
    time.sleep(7)
    
   
    
    # click 3 tims
    
    cl1 = driver.find_element(By.XPATH,"/html/body/div[4]/div[3]/div/div[2]/div/div[2]/main/div[2]/div/div[1]/div/div/section/div[1]/div[2]/div/button[2]")
    cl1.click()
    cl1.click()
    cl1.click()
    
    
    data1 = driver.find_element(By.XPATH,"/html/body/div[4]/div[3]/div/div[2]/div/div[2]/main/div[2]/div/div[1]/div/div/section/div[2]/ul/li[4]/div/div/div")
    time.sleep(5)
    cl = driver.find_element(By.XPATH,"/html/body/div[4]/div[3]/div/div[2]/div/div[2]/main/div[2]/div/div[1]/div/button")
    cl.click()
    # print(data1.text)
    time.sleep(5)
    
    # data1 = []
    # for i in data1:
    #     print(i)
    
    data=[]
    s1 = pd.DataFrame(data)
    data.append(data1.text)
    with open('kolkata_people.csv', 'a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(s1)
    
   
    
    
    
    
    
    
    # for x in range(20):
    #     try:
    #         btn =  driver.find_element(By.XPATH,"/html/body/div[5]/div[3]/div/div[2]/div/div[2]/main/div[2]/div/div[1]/div/div/section/div[2]/ul/li[4]/div/div/div/button["+str(x)+"]")
    #         print(btn.text)
    #     except:
    #         break
        
    driver.back()
    driver.back()
    driver.back()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[16], line 28
#      22 time.sleep(7)
#      26 # click 3 tims
# ---> 28 cl1 = driver.find_element(By.XPATH,"/html/body/div[4]/div[3]/div/div[2]/div/div[2]/main/div[2]/div/div[1]/div/div/section/div[1]/div[2]/div/button[2]")
#      29 cl1.click()
#      30 cl1.click()
#
# File c:\Users\tusha\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:742, in WebDriver.find_element(self, by, value)
#     739     by = By.CSS_SELECTOR
#     740     value = f'[name="{value}"]'
# --> 742 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\tusha\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:348, in WebDriver.execute(self, driver_command, params)
# ...

# %%
cl1 = driver.find_element(By.XPATH, "/html/body/div[4]/div[3]/div/div[2]/div/div[2]/main/div[2]/div/div[1]/div/div/section/div[1]/div[2]/div/button[2]")
cl1.click()
cl1.click()
cl1.click()
